# %%
import keras_ocr
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for C:\Users\Lenovo\.keras-ocr\craft_mlt_25k.h5
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# WARNING:tensorflow:From c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Looking for C:\Users\Lenovo\.keras-ocr\crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(img) for img in ['D:/DocuVille/backend/images/DL1.jpg',
                                          'D:/DocuVille/backend/images/PP_1.jpeg']
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize=(10,20))
plt.imshow(images[0])

# %%
plt.imshow(images[1])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# ...
# 4/4 [==============================] - 5s 797ms/step

# %%
fig,axs = plt.subplots(nrows=len(images),figsize=(10,20))
for ax,image,predictions in zip(axs,images,prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image,
                                    predictions=predictions,
                                    ax=ax)

# %%
for i in prediction_groups:
    for y in i:
        print(y[0])
# Out:
# indian
# union
# driving
# licence
# up
# uttar
# pradesh
# issued
# by
# up63
# 19981633749
# hetia
# gtad
# validity
# validitytryh
# nt
# date
# issue
# 13062024
# 21062031
# holders
# signature
# mahesh
# pratap
# singh
# namer
# 22061971
# n
# of
# birth
# blood
# date
# group
# organ
# donor
# rajendra
# prata
# p
# singh
# sonidaughternwife
# of
# addressi
# rampurghat
# marg
# rural
# nibi
# gaharwar
# mirzapurjup
# 231303
# tie
# rure
# republic
# of
# india
# croe
# ype
# d
# county
# coas
# pallkan
# p
# ho
# ind
# l
# a799279
# surnsne
# ctel
# chheda
# teen
# given
# namos
# chintan
# darshita
# dkbnd
# teun
# sen
# sal
# natlonsily
# saa
# indian
# 1986
# sstonl
# birin
# place
# ol
# maarashtra
# munbaln
# istue
# ot
# place
# sual
# cur
# se
# mumbai
# ol
# ian
# date
# ouuda
# sis
# 2111012023
# 2211012018
#
# s

# %%
import pandas as pd
df = pd.DataFrame(prediction_groups[0], columns=['text', 'bbox'])
words = list(map(str.upper,df['text'].tolist()))
sentence = ' '.join(words)
sentence
# Out:
# 'INDIAN UNION DRIVING LICENCE UP UTTAR PRADESH ISSUED BY UP63 19981633749 HETIA GTAD VALIDITY VALIDITYTRYH NT DATE ISSUE 13062024 21062031 HOLDERS SIGNATURE MAHESH PRATAP SINGH NAMER 22061971 N OF BIRTH BLOOD DATE GROUP ORGAN DONOR RAJENDRA PRATA P SINGH SONIDAUGHTERNWIFE OF ADDRESSI RAMPURGHAT MARG RURAL NIBI GAHARWAR MIRZAPURJUP 231303'
